# %% [markdown]
# <a href="https://colab.research.google.com/github/isnanramalia/cryptography2023/blob/main/superenkrip/HillCipher_Isna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import random
import re

option = 0

# Kamus Huruf ke Angka
substitusi = {
    'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'J': 9,
    'K': 10, 'L': 11, 'M': 12, 'N': 13, 'O': 14, 'P': 15, 'Q': 16, 'R': 17, 'S': 18,
    'T': 19, 'U': 20, 'V': 21, 'W': 22, 'X': 23, 'Y': 24, 'Z': 25, ' ': 26, 'a': 27,
    'b': 28, 'c': 29, 'd': 30, 'e': 31, 'f': 32, 'g': 33, 'h': 34, 'i': 35, 'j': 36,
    'k': 37, 'l': 38, 'm': 39, 'n': 40, 'o': 41, 'p': 42, 'q': 43, 'r': 44, 's': 45,
    't': 46, 'u': 47, 'v': 48, 'w': 49, 'x': 50, 'y': 51, 'z': 52, '!': 53, '?': 54,
    '.': 55, ',': 56}

# Membalik Variabel Substitusi menjadi "Angka : Huruf" || 0 : 'A' dst.
inverse_substitution = {angka: huruf for huruf, angka in substitusi.items()}


def encrypt(plain_text, key_matrix):
    # Convert Plain Text ke Huruf Besar
    plain_text = plain_text

    # Menghilangkan karakter selain yang ada di variabel substitusi
    hasil = ""

    for i in plain_text:
        if i in substitusi:
            hasil += i

    plain_text = hasil

    # Jika panjang Plain Text tidak sekelipatan dengan besar matriks kita tambahkan huruf 'X'
    # Jika matriksnya 2x2, contoh : "BA MB AN G" maka akan dirubah menjadi "BA MB AN GX"
    # Jika matriksnya 3x3, contoh : "BAM BAN G" maka akan dirubah menjadi "BAM BAN GXX"
    if len(plain_text) % len(key_matrix) != 0:
        padding_length = len(key_matrix) - (len(plain_text) % len(key_matrix))
        plain_text += 'X' * padding_length

    # Tempat untuk menyimpan Cipher Text
    cipher_text = ''

    print('Plain Text Bersih : ', plain_text)
    print('Key Matrix : \n', key_matrix)

    # Looping Enkripsi
    for i in range(0, len(plain_text), len(key_matrix)):
        # Mengambil plaintext huruf ke i sampai i + len(key_matrix)
        block = plain_text[i:i+len(key_matrix)]

        # Konversi plaintext menjadi angka.
        block_vector = np.array([substitusi[text] for text in block])
        print("\nPlaintext : ", block_vector)

        # Perkalian Vector, kemudian di modulokan 27. 26 dari alphabet 1 untuk karakter spasi.
        # encrypted_vector = np.dot(block_vector, key_matrix) % 27
        encrypted_vector = np.dot(key_matrix, block_vector) % 57
        print("Ciphertext : ", encrypted_vector)

        # Konversi Angka ke Huruf
        encrypted_block = ''.join([inverse_substitution[num]
                                  for num in encrypted_vector])
        print("Ciphertext : ", encrypted_block)

        # Cipher Text ditampung di variabel bernama cipher_text
        cipher_text += encrypted_block

    return cipher_text

# Fungsi untuk mencari modulo invers


def mod_inverse(a, m):
    for x in range(1, m):
        if (a * x) % m == 1:
            return x
    return None


def decrypt(cipher_text, key_matrix):

    # Convert Cipher Text ke Huruf Besar
    cipher_text = cipher_text

    # Mencari determinan dengan menggunakan numpy, kemudian angkanya di bulatkan.
    determinant = int(np.round(np.linalg.det(key_matrix)))
    print("\nDeterminan : ", determinant)

    determinant = determinant % 57
    print("K^-1 : ", determinant)

    # Mencari modulo invers dari determinan
    modulo_inverse = mod_inverse(determinant, 57)

    print("Invers Modulo : ", modulo_inverse)

    if modulo_inverse is None:
        return "Determinan tidak memiliki invers modulo 57"
    else:
        # Membuat variabel penampung baru, besarnya sama seperti key_matrix.
        # Jika key_matrix berukuran 3x3, maka adjoint_matrix akan berukuran 3x3 juga.
        adjoint_matrix = np.zeros_like(key_matrix, dtype=np.int64)

        # key_matrix.shape isinya yaitu ukuran matriks.
        # Jika key_matrix berukuran 3x3, maka key_matrix.shape akan bernilai [3,3]
        for i in range(key_matrix.shape[0]):
            for j in range(key_matrix.shape[1]):
                # Axis 0 artinya baris, Axis 1 artinya kolom.
                # Untuk mendapatkan sub_matrix, kita menghapus baris dan kolom pada matriks itu.
                # Contoh : 2 1 1 | Misal pada posisi pertama i = 0 ; j = 0, kita akan menghapus
                #          3 5 2 | baris dan kolom "2" menyisakan | 5 2 | sebagai sub_matrix nya.
                #          3 3 3 |                                | 3 3 |
                sub_matrix = np.delete(
                    np.delete(key_matrix, i, axis=0), j, axis=1)
                # Kemudian, mencari determinan dari sub_matrix tersebut.
                cofactor = int(np.round(np.linalg.det(sub_matrix)))
                # Melihat apakah i+j ganjil/genap. Jika i+j ganjil, maka angka didepan menjadi "1"
                # Jika i+j genap, maka angka didepan menjadi "-1"
                adjoint_matrix[j, i] = ((-1) ** (i + j)) * cofactor

        # Mencari Kunci Matriks Invers dengan mengalikan adjoint_matrix dengan Modulo Invers dan di modulo 27.
        key_matrix_inv = (adjoint_matrix * modulo_inverse) % 57

    # Tempat untuk menyimpan Plain Text hasil dekripsi
    plain_text = ''

    # Looping Dekripsi
    for i in range(0, len(cipher_text), len(key_matrix)):
        # Mengambil Cipher Text huruf ke i sampai i + len(key_matrix)
        block = cipher_text[i:i+len(key_matrix)]

        # Konversi Cipher Text menjadi angka.
        block_vector = np.array([substitusi[text] for text in block])
        print("\nCiphertext : ", block_vector)

        # Dekripsi dengan mengalikan matriks kunci invers dengan vektor ciphertext
        # decrypted_vector = np.dot(block_vector, key_matrix_inv) % 27
        decrypted_vector = np.dot(key_matrix_inv, block_vector) % 57
        print("Plaintext : ", decrypted_vector)

        # Konversi vektor hasil dekripsi menjadi huruf
        decrypted_block = ''.join([inverse_substitution[num]
                                  for num in decrypted_vector])
        print("Plaintext : ", decrypted_block)

        # Plain Text ditampung di variabel bernama plain_text
        plain_text += decrypted_block

    # Mengreplace karakter "_" dengan spasi " ".
    return plain_text


def buatkeymatrix(string_input):
    # Menghitung panjang string
    panjang_string = len(string_input)

    # Menghitung ukuran matriks m x m
    m = int(math.sqrt(panjang_string))

    # Memastikan bahwa panjang string sesuai dengan ukuran matriks m x m
    if m * m != panjang_string:
        print("Panjang string tidak cocok dengan ukuran matriks m x m.")
        return
    else:
        # Membuat matriks m x m dengan huruf dari string input
        key_matrix = np.array([substitusi[text]
                              for text in string_input]).reshape(m, m)

        return key_matrix


def generatekey(panjang):
    randomtext = []
    # Mengulang berdasarkan panjang yang diinginkan
    for i in range(panjang):
        # Menghasilkan angka acak dari 0-26, kemudian disimpan kedalam array.
        randomtext.append(random.randint(0, 56))
    # Mengubah angka menjadi huruf sesuai substitusi.
    randomtext_array = np.array(
        [inverse_substitution[text] for text in randomtext])
    # Mengabungkan array menjadi satu string utuh.
    result = ''.join(randomtext_array)

    return result


def cekrekomendasi(kunci):
    result = ""
    cek = 0

    # Looping berdasarkan panjang kunci.
    for i in range(len(kunci)):
        # Looping mencoba kombinasi huruf sebanyak 10000 kali.
        for j in range(10000):
            # Menghasilkan huruf untuk mengreplace bagian belakang.
            huruf = generatekey(i+1)
            # Menghapus string belakang yang kemudian di replace oleh huruf random.
            text = kunci[0:len(kunci)-i-1] + huruf
            # Mengubah text menjadi matriks m x m
            text_vector = np.array([substitusi[huruf] for huruf in text]).reshape(
                int(math.sqrt(len(text))), int(math.sqrt(len(text))))
            # Mencari Determinan
            determinant = int(np.round(np.linalg.det(text_vector)))
            # Mencari Modulo Invers
            modulo_inverse = mod_inverse(determinant, 57)
            # Jika Modulo Invers Ditemukan, return result. cek = 1 untuk keluar dari looping.
            if modulo_inverse is not None:
                result = text
                cek = 1
            if cek == 1:
                break
        if cek == 1:
            break
    return result


while (option != "1" or option != "2" or option != "3"):
    option = input(
        '\nHill Cipher\n1. Encrypt\n2. Decrypt\n3. Cek Kunci\n4. Exit\nInput : ')

    if (option == "1"):
        plain_text = input('Insert Plain Text : ')
        kunci = input('Insert Kunci : ')
        kunci = kunci
        key_matrix = buatkeymatrix(kunci)
        if key_matrix is None:
            break
        cipher_text = encrypt(plain_text, key_matrix)
        print("\nCipher Text : ", cipher_text)
    elif (option == "2"):
        cipher_text = input('Insert Cipher Text : ')
        kunci = input('Insert Kunci : ')
        kunci = kunci
        key_matrix = buatkeymatrix(kunci)
        if key_matrix is None:
            break
        plain_text_decrypted = decrypt(cipher_text, key_matrix)
        print("\nPlain Text : ", plain_text_decrypted)
    elif (option == "3"):
        kunci = input('Insert Kunci : ')
        kunci = kunci
        key_matrix = buatkeymatrix(kunci)
        if key_matrix is None:
            break
        determinant = int(np.round(np.linalg.det(key_matrix)))
        result = mod_inverse(determinant, 57)
        if result is not None:
            kunciditemukan = 1
            print('Modulo Invers dari {kunci} adalah ', result)
        else:
            rekomendasi = cekrekomendasi(kunci)
            print('Kunci Tersebut Tidak Memiliki Modulo Invers.')
            print('Rekomendasi : ', rekomendasi)
    elif (option == "4"):
        exit()
# Out:
# Hill Cipher
# 1. Encrypt
# 2. Decrypt
# 3. Cek Kunci
# 4. Exit
# Input : 3
# Insert Kunci : isnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaiNtC
# Modulo Invers dari {kunci} adalah  17
#
# Hill Cipher
# 1. Encrypt
# 2. Decrypt
# 3. Cek Kunci
# 4. Exit
# Input : 1
# Insert Plain Text : Perjuangan B.J. Habibie Saat Kuliah di Jerman Perjuangan B.J. Habibie Saat Kuliah di Jerman Ini Akan Menginspirasi Kalian Kali ini kita akan kembali dengan kisah inspiratif dari salah satu orang hebat dari Indonesia yaitu B.J. Habibie. Beliau juga memiliki kisah hidup yang patut untuk diteladani. Salah satunya adalah kisah hidup beliau saat menyelesaikan kuliah di Jerman. Kalian penasaran dengan kisah beliau? Simak ulasannya berikut ini ya! Menimba Ilmu Di Jerman Dengan Biaya Sendiri B.J. Habibie muda merupakan salah satu anak muda Indonesia yang memiliki semangat juang tinggi dalam ilmu pendidikan. Melanjutkan pendidikan di Jerman bisa dibilang sebagai salah satu keputusan hidup yang menantang dalam hidup beliau. Sebelum melanjutkan pendidikan di Jerman, sebenarnya B.J. Habibie sudah mengambil kuliah elektro di ITB selama 6 bulan. Namun setelahnya, beliau memutuskan untuk melanjutkan pendidikan S1 dan S2 nya di Jerman. Beliau bertekad menjadi orang yang berguna bagi bangsanya dan memiliki citacita untuk membuat pesawat terbang yang bisa membawa rakyat Indonesia ke titiktitik maritim luas di Indonesia. Tentunya beliau ingin mimpi ini diwujudkan dengan keringat rakyat bukannya biaya hasil ekspor sumber daya alam atau utang luar negeri. Berawal dari citacita mulia inilah beliau melanjutkan mimpinya di Jerman. Dalam menempuh pendidikan di Jerman, beliau tidak mendapatkan beasiswa melainkan dengan biaya sendiri dari orang tuanya. Apakah jaman dulu belum ada beasiswa, atau beliau tidak mampu mendapatkannya? Faktanya, orang tua B.J. Habibie merasa bahwa pendidikan anaknya tidak boleh dibiayai oleh orang lain. Semua biaya ditanggung oleh kedua orang tuanya meskipun mereka bukan berasal dari kalangan berada. Ibu beliau memiliki usaha catering dan koskosan. Jerih Payah B.J. Habibie Selama Kuliah Di Jerman Demi meringankan beban orang tua dalam membiayai pendidikannya, B.J. Habibie memilih untuk tinggal jauh dari pusat kota dengan tempat tinggal yang memiliki fasilitas seadanya. Bahkan beliau juga rela untuk berjalan kaki dari tempat tinggal ke kampus hanya demi menghemat biaya transportasi. Selain itu, selama menempuh S1 dan S2 di Jerman, beliau sempat dua kali dikira telah meninggal di Jerman selama masa itu. Namun jerih payah beliau akhirnya terbayar karena meskipun menjalani pendidikan dengan biaya yang terbatas, B.J. Habibie berhasil menyelesaikan pendidikan S1 hingga S3 dengan luar biasa baik. Setelah lulus S2 akhirnya beliau bertekad untuk bekerja sebagai asisten professor hingga beliau mendapat kesempatan untuk melanjutkan S3 dengan beasiswa. Tepat saat usia 28 tahun, B.J. Habibie resmi memperoleh gelar Doktor bidang teknologi pesawat terbang di Jerman. Usia 28 tahun dengan gelar Doktor bisa dibilang usia yang sangat belia. Bahkan banyak yang tidak percaya beliau merupakan lulusan S3, mengingat wajah beliau yang baby face. Selama hidup di Jerman, B.J. Habibie menjadi terbiasa untuk mengatasi segala permasalahan sendiri. Bahkan, beliau juga masih menerapkan nilainilai yang sudah diajarkan orang tuanya selama di Indonesia dulu saat menjalani kehidupan di Jerman. Salah satu hal yang beliau sukai di Jerman adalah perpustakaannya. Menurut beliau, perpustakaan di Jerman buka lebih lama dan lebih bebas untuk dikunjungi. Hal ini membuat B.J. Habibie merasa memiliki kesempatan yang lebih besar dalam hal menambah wawasan dan pengetahuan selama di Jerman. Lebih dari itu, ada satu cerita lucu yang dialami beliau saat menempuh studi di Jerman. Kemampuan bahasa Jerman B.J. Habibie yang di atas ratarata untuk orang asing membuat temanteman beliau mempertanyakan keturunan dan juga asal usul beliau. Bahkan pada akhirnya beliau harus menjawab dengan candaan bahwa ayahnya kanibal pernah makan daging orang Jerman sehingga sejak saat itu beliau memiliki darah Jerman. Komitmen dan tekad beliau untuk menjadi yang terbaik dan melebihi orangorang di Jerman dalam hal pengetahuan berhasil membuat beliau diakui kemampuannya oleh dunia.  ...
# Insert Kunci : isnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaisnanuramaliaiNtC
# Plain Text Bersih :  Perjuangan B.J. Habibie Saat Kuliah di Jerman Perjuangan B.J. Habibie Saat Kuliah di Jerman Ini Akan Menginspirasi Kalian Kali ini kita akan kembali dengan kisah inspiratif dari salah satu orang hebat dari Indonesia yaitu B.J. Habibie. Beliau juga memiliki kisah hidup yang patut untuk diteladani. Salah satunya adalah kisah hidup beliau saat menyelesaikan kuliah di Jerman. Kalian penasaran dengan kisah beliau? Simak ulasannya berikut ini ya! Menimba Ilmu Di Jerman Dengan Biaya Sendiri B.J. Habibie muda merupakan salah satu anak muda Indonesia yang memiliki semangat juang tinggi dalam ilmu pendidikan. Melanjutkan pendidikan di Jerman bisa dibilang sebagai salah satu keputusan hidup yang menantang dalam hidup beliau. Sebelum melanjutkan pendidikan di Jerman, sebenarnya B.J. Habibie sudah mengambil kuliah elektro di ITB selama  bulan. Namun setelahnya, beliau memutuskan untuk melanjutkan pendidikan S dan S nya di Jerman. Beliau bertekad menjadi orang yang berguna bagi bangsanya dan memiliki citacita untuk membuat pesawat terbang yang bisa membawa rakyat Indonesia ke titiktitik maritim luas di Indonesia. Tentunya beliau ingin mimpi ini diwujudkan dengan keringat rakyat bukannya biaya hasil ekspor sumber daya alam atau utang luar negeri. Berawal dari citacita mulia inilah beliau melanjutkan mimpinya di Jerman. Dalam menempuh pendidikan di Jerman, beliau tidak mendapatkan beasiswa melainkan dengan biaya sendiri dari orang tuanya. Apakah jaman dulu belum ada beasiswa, atau beliau tidak mampu mendapatkannya? Faktanya, orang tua B.J. Habibie merasa bahwa pendidikan anaknya tidak boleh dibiayai oleh orang lain. Semua biaya ditanggung oleh kedua orang tuanya meskipun mereka bukan berasal dari kalangan berada. Ibu beliau memiliki usaha catering dan koskosan. Jerih Payah B.J. Habibie Selama Kuliah Di Jerman Demi meringankan beban orang tua dalam membiayai pendidikannya, B.J. Habibie memilih untuk tinggal jauh dari pusat kota dengan tempat tinggal yang memiliki fasilitas seadanya. Bahkan beliau juga rela untuk berjalan kaki dari tempat tinggal ke kampus hanya demi menghemat biaya transportasi. Selain itu, selama menempuh S dan S di Jerman, beliau sempat dua kali dikira telah meninggal di Jerman selama masa itu. Namun jerih payah beliau akhirnya terbayar karena meskipun menjalani pendidikan dengan biaya yang terbatas, B.J. Habibie berhasil menyelesaikan pendidikan S hingga S dengan luar biasa baik. Setelah lulus S akhirnya beliau bertekad untuk bekerja sebagai asisten professor hingga beliau mendapat kesempatan untuk melanjutkan S dengan beasiswa. Tepat saat usia  tahun, B.J. Habibie resmi memperoleh gelar Doktor bidang teknologi pesawat terbang di Jerman. Usia  tahun dengan gelar Doktor bisa dibilang usia yang sangat belia. Bahkan banyak yang tidak percaya beliau merupakan lulusan S, mengingat wajah beliau yang baby face. Selama hidup di Jerman, B.J. Habibie menjadi terbiasa untuk mengatasi segala permasalahan sendiri. Bahkan, beliau juga masih menerapkan nilainilai yang sudah diajarkan orang tuanya selama di Indonesia dulu saat menjalani kehidupan di Jerman. Salah satu hal yang beliau sukai di Jerman adalah perpustakaannya. Menurut beliau, perpustakaan di Jerman buka lebih lama dan lebih bebas untuk dikunjungi. Hal ini membuat B.J. Habibie merasa memiliki kesempatan yang lebih besar dalam hal menambah wawasan dan pengetahuan selama di Jerman. Lebih dari itu, ada satu cerita lucu yang dialami beliau saat menempuh studi di Jerman. Kemampuan bahasa Jerman B.J. Habibie yang di atas ratarata untuk orang asing membuat temanteman beliau mempertanyakan keturunan dan juga asal usul beliau. Bahkan pada akhirnya beliau harus menjawab dengan candaan bahwa ayahnya kanibal pernah makan daging orang Jerman sehingga sejak saat itu beliau memiliki darah Jerman. Komitmen dan tekad beliau untuk menjadi yang terbaik dan melebihi orangorang di Jerman dalam hal pengetahuan berhasil membuat beliau diakui kemampuannya oleh dunia. Bahkan hingga ...
# Key Matrix :
#  [[35 45 40 27 40 47 44 27 39 27 38 35 27 35 45]
#  [40 27 40 47 44 27 39 27 38 35 27 35 45 40 27]
#  [40 47 44 27 39 27 38 35 27 35 45 40 27 40 47]
#  [44 27 39 27 38 35 27 35 45 40 27 40 47 44 27]
#  [39 27 38 35 27 35 45 40 27 40 47 44 27 39 27]
#  [38 35 27 35 45 40 27 40 47 44 27 39 27 38 35]
#  [27 35 45 40 27 40 47 44 27 39 27 38 35 27 35]
#  [45 40 27 40 47 44 27 39 27 38 35 27 35 45 40]
#  [27 40 47 44 27 39 27 38 35 27 35 45 40 27 40]
#  [47 44 27 39 27 38 35 27 35 45 40 27 40 47 44]
#  [27 39 27 38 35 27 35 45 40 27 40 47 44 27 39]
#  [27 38 35 27 35 45 40 27 40 47 44 27 39 27 38]
#  [35 27 35 45 40 27 40 47 44 27 39 27 38 35 27]
#  [35 45 40 27 40 47 44 27 39 27 38 35 27 35 45]
#  [40 27 40 47 44 27 39 27 38 35 27 35 13 46  2]]
#
# Plaintext :  [15 31 44 36 47 27 40 33 27 40 26  1 55  9 55]
# Ciphertext :  [42  7 16 17 17  6 43 11 20 33 42 43 39 42  4]
# Ciphertext :  pHQRRGqLUgpqmpE
#
# Plaintext :  [26  7 27 28 35 28 35 31 26 18 27 27 46 26 10]
# Ciphertext :  [34 32 35 51 47  5 41 35  5 32 53 48  8 34  5]
# Ciphertext :  hfiyuFoiFf!vIhF
#
# Plaintext :  [47 38 35 27 34 26 30 35 26  9 31 44 39 27 40]
# Ciphertext :  [35 41 45 40 25 51  4  5 17 43 51 28 38 35  7]
# Ciphertext :  iosnZyEFRqybliH
#
# Plaintext :  [26 15 31 44 36 47 27 40 33 27 40 26  1 55  9]
# Ciphertext :  [32  0 21 10 50 55 36 34 14 39 32 37 54 32 16]
# Ciphertext :  fAVKx.jhOmfk?fQ
#
# Plaintext :  [55 26  7 27 28 35 28 35 31 26 18 27 27 46 26]
# Ciphertext :  [21 38 25 31 46  4 43 14 24 29  8  0 20 21 54]
# Ciphertext :  VlZetEqOYcIAUV?
#
# Plaintext :  [10 47 38 35 27 34 26 30 35 26  9 31 44 39 27]
# Ciphertext :  [ 9 14 51 14 38 22 44 38 31  0 13  4 37  9 46]
# Ciphertext :  JOyOlWrleANEkJt
#
# Plaintext :  [40 26  8 40 35 26  0 37 27 40 26 12 31 40 33]
# Ciphertext :  [34 15 50 47 19  6 23 46 30 54 40 30 50 34 34]
# Ciphertext :  hPxuTGXtd?ndxhh
#
# Plaintext :  [35 40 45 42 35 44 27 45 35 26 10 27 38 35 27]
# Ciphertext :  [49 19 46  7 47 53 11 37  6 45 14 20 15 49 48]
# Ciphertext :  wTtHu!LkGsOUPwv
#
# Plaintext :  [40 26 10 27 38 35 26 35 40 35 26 37 35 46 27]
# Ciphertext :  [12 48 27  2 49 48 29 37 28 25 38 15 47 12 11]
# Ciphertext :  MvaCwvckbZlPuML
#
# Plaintext :  [26 27 37 27 40 26 37 31 39 28 27 38 35 26 30]
# Ciphertext :  [17 49 26 11  0  1 38 30 15  7  9  7  3 17 45]
# Ciphertext :  Rw LABldPHJHDRs
#
# Plaintext :  [31 40 33 27 40 26 37 35 45 27 34 26 35 40 45]
# Ciphertext :  [ 5 50 33 44  3  4 15 46 18 30 19 19  5  5 40]
# Ciphertext :  FxgrDEPtSdTTFFn
#
# Plaintext :  [42 35 44 27 46 35 32 26 30 27 44 35 26 45 27]
# Ciphertext :  [37 17 39 10 21 26 34 37 10 25  7 37 48 37 34]
# Ciphertext :  kRmKV hkKZHkvkh
#
# Plaintext :  [38 27 34 26 45 27 46 47 26 41 44 27 40 33 26]
# Ciphertext :  [17  0 18 45 38 31 29 29 36 14 45 47 32 17 35]
# Ciphertext :  RASsleccjOsufRi
#
# Plaintext :  [34 31 28 27 46 26 30 27 44 35 26  8 40 30 41]
# Ciphertext :  [ 7 40 27  5 28 27 11 25 29 10 18 50 35  7 24]
# Ciphertext :  HnaFbaLZcKSxiHY
#
# Plaintext :  [40 31 45 35 27 26 51 27 35 46 47 26  1 55  9]
# Ciphertext :  [ 7 28 56 34 32 15 48 54 17 29  5 19 46  7 44]
# Ciphertext :  Hb,hfPv?RcFTtHr
#
# Plaintext :  [55 26  7 27 28 35 28 35 31 55 26  1 31 38 35]
# Ciphertext :  [32  6  1 47 21 31 14 36 50 49 29 41 15 32 20]
# Ciphertext :  fGBuVeOjxwcoPfU
#
# Plaintext :  [27 47 26 36 47 33 27 26 39 31 39 35 38 35 37]
# Ciphertext :  [51 53 29 43  8  8 18 16 22  6 21 10 36 51  3]
# Ciphertext :  y!cqIISQWGVKjyD
#
# Plaintext :  [35 26 37 35 45 27 34 26 34 35 30 47 42 26 51]
# Ciphertext :  [45 34 46 19 53  6 40  2  8  1 53 30 32 45 22]
# Ciphertext :  shtT!GnCIB!dfsW
#
# Plaintext :  [27 40 33 26 42 27 46 47 46 26 47 40 46 47 37]
# Ciphertext :  [39 41 56 31 17 29 25 53  8 15 40  2 34 39 35]
# Ciphertext :  mo,eRcZ!IPnChmi
#
# Plaintext :  [26 30 35 46 31 38 27 30 27 40 35 55 26 18 27]
# Ciphertext :  [20 24 12 52 32 46 51 44 21  9 15  6 22 20 50]
# Ciphertext :  UYMzftyrVJPGWUx
#
# Plaintext :  [38 27 34 26 45 27 46 47 40 51 27 26 27 30 27]
# Ciphertext :  [26 52 30 31 45 30 27 14 51 29 47 37 55 26  4]
# Ciphertext :   zdesdaOycuk. E
#
# Plaintext :  [38 27 34 26 37 35 45 27 34 26 34 35 30 47 42]
# Ciphertext :  [ 8 15 15 24 33 29 29 29 19 24 12 47  4  8 54]
# Ciphertext :  IPPYgcccTYMuEI?
#
# Plaintext :  [26 28 31 38 35 27 47 26 45 27 27 46 26 39 31]
# Ciphertext :  [46  4  2 26 16 11 41 27 17 29  9 30 45 46 56]
# Ciphertext :  tEC QLoaRcJdst,
#
# Plaintext :  [40 51 31 38 31 45 27 35 37 27 40 26 37 47 38]
# Ciphertext :  [56 55 48 55 53 39 31 37 41 20 29 23 11 56 27]
# Ciphertext :  ,.v.!mekoUcXL,a
#
# Plaintext :  [35 27 34 26 30 35 26  9 31 44 39 27 40 55 26]
# Ciphertext :  [ 6 38 44 14 21 52 14  8 35 45 29  1 56  6 34]
# Ciphertext :  GlrOVzOIiscB,Gh
#
# Plaintext :  [10 27 38 35 27 40 26 42 31 40 27 45 27 44 27]
# Ciphertext :  [29 25 46 39 14 36 25  6 19 17  6  9  8 29  4]
# Ciphertext :  cZtmOjZGTRGJIcE
#
# Plaintext :  [40 26 30 31 40 33 27 40 26 37 35 45 27 34 26]
# Ciphertext :  [21 39 14  9 32 15 26 49 37  3  8 51 26 21 40]
# Ciphertext :  VmOJfP wkDIy Vn
#
# Plaintext :  [28 31 38 35 27 47 54 26 18 35 39 27 37 26 47]
# Ciphertext :  [39 28  6 18 49 48  4  9 22  5 12  5 13 39 48]
# Ciphertext :  mbGSwvEJWFMFNmv
#
# Plaintext :  [38 27 45 27 40 40 51 27 26 28 31 44 35 37 47]
# Ciphertext :  [21 51 29  5 42 29 19 14 25 40 10  3 48 21 30]
# Ciphertext :  VycFpcTOZnKDvVd
#
# Plaintext :  [46 26 35 40 35 26 51 27 53 26 12 31 40 35 39]
# Ciphertext :  [16 45 28 43 56 37 29 47  1 10 51 39 18 16 52]
# Ciphertext :  Qsbq,kcuBKymSQz
#
# Plaintext :  [28 27 26  8 38 39 47 26  3 35 26  9 31 44 39]
# Ciphertext :  [54 41  1  3  7 16 39 34 32  1 22 45 53 54 48]
# Ciphertext :  ?oBDHQmhfBWs!?v
#
# Plaintext :  [27 40 26  3 31 40 33 27 40 26  1 35 27 51 27]
# Ciphertext :  [ 5 20 15 41 20 39 37 35 27  7 26 51 31  5 41]
# Ciphertext :  FUPoUmkiaH yeFo
#
# Plaintext :  [26 18 31 40 30 35 44 35 26  1 55  9 55 26  7]
# Ciphertext :  [19 25 36 52  1 22 24 39 49 33 53 12 49 19 13]
# Ciphertext :  TZjzBWYmwg!MwTN
#
# Plaintext :  [27 28 35 28 35 31 26 39 47 30 27 26 39 31 44]
# Ciphertext :  [43 41 56  4 54 39 40 25  7  0 34 27 14 43 45]
# Ciphertext :  qo,E?mnZHAhaOqs
#
# Plaintext :  [47 42 27 37 27 40 26 45 27 38 27 34 26 45 27]
# Ciphertext :  [24  7 47 16  5 26 27 47 31 48 15 24 55 24 24]
# Ciphertext :  YHuQF auevPY.YY
#
# Plaintext :  [46 47 26 27 40 27 37 26 39 47 30 27 26  8 40]
# Ciphertext :  [53  5 32 33 23  3 43  4 22 34  2 20 53 53 45]
# Ciphertext :  !FfgXDqEWhCU!!s
#
# Plaintext :  [30 41 40 31 45 35 27 26 51 27 40 33 26 39 31]
# Ciphertext :  [28 33 27 24 15  3 56 41 27 43 46 46 31 28 28]
# Ciphertext :  bgaYPD,oaqttebb
#
# Plaintext :  [39 35 38 35 37 35 26 45 31 39 27 40 33 27 46]
# Ciphertext :  [46 27 30 52 17 20 52 35  4 52 25 21 33 46 35]
# Ciphertext :  tadzRUziEzZVgti
#
# Plaintext :  [26 36 47 27 40 33 26 46 35 40 33 33 35 26 30]
# Ciphertext :  [39 29 28 11 39 51 19 26 21 39 24 30 43 39 25]
# Ciphertext :  mcbLmyT VmYdqmZ
#
# Plaintext :  [27 38 27 39 26 35 38 39 47 26 42 31 40 30 35]
# Ciphertext :  [24 35 14 16 41 51  0  9 21 51 35 20 16 24 55]
# Ciphertext :  YiOQoyAJVyiUQY.
#
# Plaintext :  [30 35 37 27 40 55 26 12 31 38 27 40 36 47 46]
# Ciphertext :  [56 46 43 41 29 11 49 41  1 27 54 23 17 56 21]
# Ciphertext :  ,tqocLwoBa?XR,V
#
# Plaintext :  [37 27 40 26 42 31 40 30 35 30 35 37 27 40 26]
# Ciphertext :  [36 40 47  7 47 23 32 22  7 39 24 31  8 36 20]
# Ciphertext :  jnuHuXfWHmYeIjU
#
# Plaintext :  [30 35 26  9 31 44 39 27 40 26 28 35 45 27 26]
# Ciphertext :  [43 41  9 25 46 37 47 34 42 12 47 18  7 43 51]
# Ciphertext :  qoJZtkuhpMuSHqy
#
# Plaintext :  [30 35 28 35 38 27 40 33 26 45 31 28 27 33 27]
# Ciphertext :  [ 3 21  6 32 46 39  1 55 14 38 48 18 27  3 48]
# Ciphertext :  DVGftmB.OlvSaDv
#
# Plaintext :  [35 26 45 27 38 27 34 26 45 27 46 47 26 37 31]
# Ciphertext :  [28 47 56 47 17 23 29 55 56  5 24 43 29 28 30]
# Ciphertext :  bu,uRXc.,FYqcbd
#
# Plaintext :  [42 47 46 47 45 27 40 26 34 35 30 47 42 26 51]
# Ciphertext :  [17 44 38 21 44  8 22 47 41  9 32 15  1 17 32]
# Ciphertext :  RrlVrIWuoJfPBRf
#
# Plaintext :  [27 40 33 26 39 31 40 27 40 46 27 40 33 26 30]
# Ciphertext :  [13 12 30 26 24 36 33 43 46 33 42  0 55 13 15]
# Ciphertext :  NMd YjgqtgpA.NP
#
# Plaintext :  [27 38 27 39 26 34 35 30 47 42 26 28 31 38 35]
# Ciphertext :  [42 42 39  1 20 14 29  1  7 22 52 14 23 42 56]
# Ciphertext :  ppmBUOcBHWzOXp,
#
# Plaintext :  [27 47 55 26 18 31 28 31 38 47 39 26 39 31 38]
# Ciphertext :  [47 48 36 10 39 12 31 30 37 48 15 35 17 47 31]
# Ciphertext :  uvjKmMedkvPiRue
#
# Plaintext :  [27 40 36 47 46 37 27 40 26 42 31 40 30 35 30]
# Ciphertext :  [32 11 40  8 44 28 27 27 31 13 35  2 17 32 50]
# Ciphertext :  fLnIrbaaeNiCRfx
#
# Plaintext :  [35 37 27 40 26 30 35 26  9 31 44 39 27 40 56]
# Ciphertext :  [34 17 34  0 42 30 12 17 37 12 39 21 53 34 45]
# Ciphertext :  hRhApdMRkMmV!hs
#
# Plaintext :  [26 45 31 28 31 40 27 44 40 51 27 26  1 55  9]
# Ciphertext :  [44 56  2 48 48 37 12 55  8 50 20  2 50 44 15]
# Ciphertext :  r,CvvkM.IxUCxrP
#
# Plaintext :  [55 26  7 27 28 35 28 35 31 26 45 47 30 27 34]
# Ciphertext :  [41 32 27 55 41 12 36 43 29 31 21 40 24 41 37]
# Ciphertext :  ofa.oMjqceVnYok
#
# Plaintext :  [26 39 31 40 33 27 39 28 35 38 26 37 47 38 35]
# Ciphertext :  [27 41  2 11 13 32  4  9 33  2  0 28  2 27 56]
# Ciphertext :  aoCLNfEJgCAbCa,
#
# Plaintext :  [27 34 26 31 38 31 37 46 44 41 26 30 35 26  8]
# Ciphertext :  [ 4 51 20  9 48 22 37 28  0 13 10 13 48  4 27]
# Ciphertext :  EyUJvWkbANKNvEa
#
# Plaintext :  [19  1 26 45 31 38 27 39 27 26 26 28 47 38 27]
# Ciphertext :  [37  4 47 22 16 29 25  7 14 22 43 16  9 37 48]
# Ciphertext :  kEuWQcZHOWqQJkv
#
# Plaintext :  [40 55 26 13 27 39 47 40 26 45 31 46 31 38 27]
# Ciphertext :  [ 4 19 46 23  5 39 13 42 43 12 40 18 23  4  5]
# Ciphertext :  ETtXFmNpqMnSXEF
#
# Plaintext :  [34 40 51 27 56 26 28 31 38 35 27 47 26 39 31]
# Ciphertext :  [14 17 21  2 53  5 12 24 22 45 40 39 51 14 12]
# Ciphertext :  ORVC!FMYWsnmyOM
#
# Plaintext :  [39 47 46 47 45 37 27 40 26 47 40 46 47 37 26]
# Ciphertext :  [54  7 27 31 33 51 28 39 35 22 10 42 26 54 13]
# Ciphertext :  ?HaegybmiWKp ?N
#
# Plaintext :  [39 31 38 27 40 36 47 46 37 27 40 26 42 31 40]
# Ciphertext :  [54 50 35 41 17 12 14 42 42 28 12 30 19 54  1]
# Ciphertext :  ?xioRMOppbMdT?B
#
# Plaintext :  [30 35 30 35 37 27 40 26 18 26 30 27 40 26 18]
# Ciphertext :  [25 39 31 11  8 27 53 51 53  8  4 38  0 25  4]
# Ciphertext :  ZmeLIa!y!IElAZE
#
# Plaintext :  [26 40 51 27 26 30 35 26  9 31 44 39 27 40 55]
# Ciphertext :  [19  3 17 15 31  8  0 48 31 46 28  1 47 19 56]
# Ciphertext :  TDRPeIAvetbBuT,
#
# Plaintext :  [26  1 31 38 35 27 47 26 28 31 44 46 31 37 27]
# Ciphertext :  [ 4  6 15 45 21 18 31 15  0  5 43 47 35  4 43]
# Ciphertext :  EGPsVSePAFquiEq
#
# Plaintext :  [30 26 39 31 40 36 27 30 35 26 41 44 27 40 33]
# Ciphertext :  [47 38 56 44 39 19 15 28 39 15 18 13 22 47 14]
# Ciphertext :  ul,rmTPbmPSNWuO
#
# Plaintext :  [26 51 27 40 33 26 28 31 44 33 47 40 27 26 28]
# Ciphertext :  [29 12  5 42 25  1 20 19 34 46 40 42 51 29 29]
# Ciphertext :  cMFpZBUThtnpycc
#
# Plaintext :  [27 33 35 26 28 27 40 33 45 27 40 51 27 26 30]
# Ciphertext :  [53 34 23 54 22 17 37 54  7 16  3 27 10 53  1]
# Ciphertext :  !hX?WRk?HQDaK!B
#
# Plaintext :  [27 40 26 39 31 39 35 38 35 37 35 26 29 35 46]
# Ciphertext :  [ 7 28 13 41 33  1 53  5 53 35  0 44 47  7 41]
# Ciphertext :  HbNogB!F!iAruHo
#
# Plaintext :  [27 29 35 46 27 26 47 40 46 47 37 26 39 31 39]
# Ciphertext :  [ 6 27 48 42 13  8 32 25 11 17 36 41 15  6 42]
# Ciphertext :  GavpNIfZLRjoPGp
#
# Plaintext :  [28 47 27 46 26 42 31 45 27 49 27 46 26 46 31]
# Ciphertext :  [ 7 51 37 56 14 11 21 20 13 23 23 22 53  7 31]
# Ciphertext :  Hyk,OLVUNXXW!He
#
# Plaintext :  [44 28 27 40 33 26 51 27 40 33 26 28 35 45 27]
# Ciphertext :  [47 56  2 25  3 21  5 17 17 43 29 16 16 47 13]
# Ciphertext :  u,CZDVFRRqcQQuN
#
# Plaintext :  [26 39 31 39 28 27 49 27 26 44 27 37 51 27 46]
# Ciphertext :  [52 12 37  6 45  2 45 13 43 45 14 43 36 52 14]
# Ciphertext :  zMkGsCsNqsOqjzO
#
# Plaintext :  [26  8 40 30 41 40 31 45 35 27 26 37 31 26 46]
# Ciphertext :  [18 24 42 53 28 52 16 12 20 46 14 49  7 18 33]
# Ciphertext :  SYp!bzQMUtOwHSg
#
# Plaintext :  [35 46 35 37 46 35 46 35 37 26 39 27 44 35 46]
# Ciphertext :  [56 19 46 39 17  3 20 38 10 49 53 37 54 56  8]
# Ciphertext :  ,TtmRDUlKw!k?,I
#
# Plaintext :  [35 39 26 38 47 27 45 26 30 35 26  8 40 30 41]
# Ciphertext :  [52 32 20 12 56 12 49  0 25  2 19 17 31 52 16]
# Ciphertext :  zfUM,MwAZCTRezQ
#
# Plaintext :  [40 31 45 35 27 55 26 19 31 40 46 47 40 51 27]
# Ciphertext :  [47 52  1  8 32 56  2 50 42 41 37  6 46 47 56]
# Ciphertext :  uzBIf,CxpokGtu,
#
# Plaintext :  [26 28 31 38 35 27 47 26 35 40 33 35 40 26 39]
# Ciphertext :  [19 11 23  6 37 10 42 47 34 52 32 23 15 19 21]
# Ciphertext :  TLXGkKpuhzfXPTV
#
# Plaintext :  [35 39 42 35 26 35 40 35 26 30 35 49 47 36 47]
# Ciphertext :  [45  1 16 24  4  5 56  5 29 55  8 54 16 45 46]
# Ciphertext :  sBQYEF,Fc.I?Qst
#
# Plaintext :  [30 37 27 40 26 30 31 40 33 27 40 26 37 31 44]
# Ciphertext :  [39 14 10 33  6 23 53 42 10 12 33 40 45 39 25]
# Ciphertext :  mOKgGX!pKMgnsmZ
#
# Plaintext :  [35 40 33 27 46 26 44 27 37 51 27 46 26 28 47]
# Ciphertext :  [47  6 38 44 42 25 15 31 22  6 55 44 30 47 48]
# Ciphertext :  uGlrpZPeWG.rduv
#
# Plaintext :  [37 27 40 40 51 27 26 28 35 27 51 27 26 34 27]
# Ciphertext :  [15 48  4 52  2 47 44 56  9 32 48  3  3 15 56]
# Ciphertext :  PvEzCur,JfvDDP,
#
# Plaintext :  [45 35 38 26 31 37 45 42 41 44 26 45 47 39 28]
# Ciphertext :  [18 25 50 22 43  1 34 48 12  1 47 43 40 18 50]
# Ciphertext :  SZxWqBhvMBuqnSx
#
# Plaintext :  [31 44 26 30 27 51 27 26 27 38 27 39 26 27 46]
# Ciphertext :  [ 1 40 52  3 50 11 44 38 13  4 19  8 29  1 44]
# Ciphertext :  BnzDxLrlNETIcBr
#
# Plaintext :  [27 47 26 47 46 27 40 33 26 38 47 27 44 26 40]
# Ciphertext :  [19 54  0 18 11 37 47 46  6 53 22 20 30 19 25]
# Ciphertext :  T?ASLkutG!WUdTZ
#
# Plaintext :  [31 33 31 44 35 55 26  1 31 44 27 49 27 38 26]
# Ciphertext :  [53 35 56  5 49 46 27  8 51 45  9  5 13 53  3]
# Ciphertext :  !i,FwtaIysJFN!D
#
# Plaintext :  [30 27 44 35 26 29 35 46 27 29 35 46 27 26 39]
# Ciphertext :  [28 45 38 53 42 24 48 45 35 35 22 27  5 28 15]
# Ciphertext :  bsl!pYvsiiWaFbP
#
# Plaintext :  [47 38 35 27 26 35 40 35 38 27 34 26 28 31 38]
# Ciphertext :  [28 14 38 34 31 43 10 10 40 17 36 45 47 28  7]
# Ciphertext :  bOlheqKKnRjsubH
#
# Plaintext :  [35 27 47 26 39 31 38 27 40 36 47 46 37 27 40]
# Ciphertext :  [48 42 34 33 52 13 28 20 37 50 39 13 41 48 15]
# Ciphertext :  vphgzNbUkxmNovP
#
# Plaintext :  [26 39 35 39 42 35 40 51 27 26 30 35 26  9 31]
# Ciphertext :  [43  9 22  7 14  6 26 16 37  5 28 44 40 43 52]
# Ciphertext :  qJWHOG QkFbrnqz
#
# Plaintext :  [44 39 27 40 55 26  3 27 38 27 39 26 39 31 40]
# Ciphertext :  [39 42 10 11 16 46 15  2 19 40 37 54  2 39 32]
# Ciphertext :  mpKLQtPCTnk?Cmf
#
# Plaintext :  [31 39 42 47 34 26 42 31 40 30 35 30 35 37 27]
# Ciphertext :  [52 52  4 25 13 10 19 13 23 32 37 46 40 52 18]
# Ciphertext :  zzEZNKTNXfktnzS
#
# Plaintext :  [40 26 30 35 26  9 31 44 39 27 40 56 26 28 31]
# Ciphertext :  [38 26 25 33  9  1 46  9 12 30 13 40 27 38 12]
# Ciphertext :  l ZgJBtJMdNnalM
#
# Plaintext :  [38 35 27 47 26 46 35 30 27 37 26 39 31 40 30]
# Ciphertext :  [45 40 49 48 14 29 13 54  5 22 16 22  0 45 20]
# Ciphertext :  snwvOcN?FWQWAsU
#
# Plaintext :  [27 42 27 46 37 27 40 26 28 31 27 45 35 45 49]
# Ciphertext :  [15 17 40 11  8 25 49 10 32 44 47 50 51 15 51]
# Ciphertext :  PRnLIZwKfruxyPy
#
# Plaintext :  [27 26 39 31 38 27 35 40 37 27 40 26 30 31 40]
# Ciphertext :  [35 43 42 31  0 34 53 16 14 21 22 12 19 35 36]
# Ciphertext :  iqpeAh!QOVWMTij
#
# Plaintext :  [33 27 40 26 28 35 27 51 27 26 45 31 40 30 35]
# Ciphertext :  [17 46 32 32 56  2 18 13 27 18 25  9 38 17  9]
# Ciphertext :  Rtff,CSNaSZJlRJ
#
# Plaintext :  [44 35 26 30 27 44 35 26 41 44 27 40 33 26 46]
# Ciphertext :  [ 2 10 15 16 44 41 18 35 42 56 20 54 40  2 12]
# Ciphertext :  CKPQroSip,U?nCM
#
# Plaintext :  [47 27 40 51 27 55 26  0 42 27 37 27 34 26 36]
# Ciphertext :  [ 2 23 46 24  9 24 13 51 20 46 55 51 41  2 15]
# Ciphertext :  CXtYJYNyUt.yoCP
#
# Plaintext :  [27 39 27 40 26 30 47 38 47 26 28 31 38 47 39]
# Ciphertext :  [20 48 45 31 10 22  6 39 50 54 43 53  5 20 20]
# Ciphertext :  UvseKWGmx?q!FUU
#
# Plaintext :  [26 27 30 27 26 28 31 27 45 35 45 49 27 56 26]
# Ciphertext :  [19 29  0 32 18 32 12 21 14  1 50 49  2 19 48]
# Ciphertext :  TcAfSfMVOBxwCTv
#
# Plaintext :  [27 46 27 47 26 28 31 38 35 27 47 26 46 35 30]
# Ciphertext :  [21 12 36  9  4 41  5 45 39  8  2 34 17 21 52]
# Ciphertext :  VMjJEoFsmIChRVz
#
# Plaintext :  [27 37 26 39 27 39 42 47 26 39 31 40 30 27 42]
# Ciphertext :  [42 14 23 26 49  8 47 51 21 49 29 34 39 42 47]
# Ciphertext :  pOX wIuyVwchmpu
#
# Plaintext :  [27 46 37 27 40 40 51 27 54 26  5 27 37 46 27]
# Ciphertext :  [ 7 38 36 40 46 18 53 18 26 12 42 44 22  7 51]
# Ciphertext :  HljntS!S MprWHy
#
# Plaintext :  [40 51 27 56 26 41 44 27 40 33 26 46 47 27 26]
# Ciphertext :  [ 3 34 16 12 11 41 12 56 53 50 24 27 36  3 37]
# Ciphertext :  DhQMLoM,!xYajDk
#
# Plaintext :  [ 1 55  9 55 26  7 27 28 35 28 35 31 26 39 31]
# Ciphertext :  [48 15 43 28 45 55 29 55 40 10 40 40  5 48 10]
# Ciphertext :  vPqbs.c.nKnnFvK
#
# Plaintext :  [44 27 45 27 26 28 27 34 49 27 26 42 31 40 30]
# Ciphertext :  [20 30 50 34 25 40 44 45 24  1 42  9 56 20 10]
# Ciphertext :  UdxhZnrsYBpJ,UK
#
# Plaintext :  [35 30 35 37 27 40 26 27 40 27 37 40 51 27 26]
# Ciphertext :  [40  4 30 28 15 31 24 37  0  2 52 37 36 40 50]
# Ciphertext :  nEdbPeYkACzkjnx
#
# Plaintext :  [46 35 30 27 37 26 28 41 38 31 34 26 30 35 28]
# Ciphertext :  [16 33 31 34 16 19 15 28 31 35  5 12 37 16  8]
# Ciphertext :  QgehQTPbeiFMkQI
#
# Plaintext :  [35 27 51 27 35 26 41 38 31 34 26 41 44 27 40]
# Ciphertext :  [49 26 31  2 45 11 17 10 43 56 13 18  0 49  3]
# Ciphertext :  w eCsLRKq,NSAwD
#
# Plaintext :  [33 26 38 27 35 40 55 26 18 31 39 47 27 26 28]
# Ciphertext :  [16 29 40 29 10 15 14 56  5 14 52  5 30 16 46]
# Ciphertext :  QcncKPO,FOzFdQt
#
# Plaintext :  [35 27 51 27 26 30 35 46 27 40 33 33 47 40 33]
# Ciphertext :  [42 39 38 29 44 36 55 16 25 18 15 47 22 42  2]
# Ciphertext :  pmlcrj.QZSPuWpC
#
# Plaintext :  [26 41 38 31 34 26 37 31 30 47 27 26 41 44 27]
# Ciphertext :  [42  6 31 36 26 48  7 11 45 47  5 33 14 42 50]
# Ciphertext :  pGej vHLsuFgOpx
#
# Plaintext :  [40 33 26 46 47 27 40 51 27 26 39 31 45 37 35]
# Ciphertext :  [24  1 29 17  7 44 54 53 41 28 22 53 11 24 17]
# Ciphertext :  YBcRHr?!obW!LYR
#
# Plaintext :  [42 47 40 26 39 31 44 31 37 27 26 28 47 37 27]
# Ciphertext :  [45 25 53 29 30 14 55 14  9 21 47 19 50 45  6]
# Ciphertext :  sZ!cdO.OJVuTxsG
#
# Plaintext :  [40 26 28 31 44 27 45 27 38 26 30 27 44 35 26]
# Ciphertext :  [48 36 41 49 12  6  4 11 53 17  3 53  9 48 12]
# Ciphertext :  vjowMGEL!RD!JvM
#
# Plaintext :  [37 27 38 27 40 33 27 40 26 28 31 44 27 30 27]
# Ciphertext :  [47  0 50 21 12 36  9 45 42 28 24 54 22 47  9]
# Ciphertext :  uAxVMjJspbY?WuJ
#
# Plaintext :  [55 26  8 28 47 26 28 31 38 35 27 47 26 39 31]
# Ciphertext :  [ 4  6 39 38 20 36  3  5 32 20 48 48 13  4  1]
# Ciphertext :  EGmlUjDFfUvvNEB
#
# Plaintext :  [39 35 38 35 37 35 26 47 45 27 34 27 26 29 27]
# Ciphertext :  [14 34 48 42 40 46 29 40  3 46 51 56 31 14 12]
# Ciphertext :  OhvpntcnDty,eOM
#
# Plaintext :  [46 31 44 35 40 33 26 30 27 40 26 37 41 45 37]
# Ciphertext :  [27 16 28 16 21  3 10 22 25  8 54 39 49 27 44]
# Ciphertext :  aQbQVDKWZI?mwar
#
# Plaintext :  [41 45 27 40 55 26  9 31 44 35 34 26 15 27 51]
# Ciphertext :  [30 27 10 19  3 35 36 22  1 16 44 34 17 30 30]
# Ciphertext :  daKTDijWBQrhRdd
#
# Plaintext :  [27 34 26  1 55  9 55 26  7 27 28 35 28 35 31]
# Ciphertext :  [51  8  0 29  2 17 50  0 20 53 56 26  6 51 29]
# Ciphertext :  yIAcCRxAU!, Gyc
#
# Plaintext :  [26 18 31 38 27 39 27 26 10 47 38 35 27 34 26]
# Ciphertext :  [18 27 10 44  3  1 50  6  6 14 20 33  5 18 28]
# Ciphertext :  SaKrDBxGGOUgFSb
#
# Plaintext :  [ 3 35 26  9 31 44 39 27 40 26  3 31 39 35 26]
# Ciphertext :  [ 7 20 25 10 15 32 36 38  1 51 20  1 26  7 42]
# Ciphertext :  HUZKPfjlByUB Hp
#
# Plaintext :  [39 31 44 35 40 33 27 40 37 27 40 26 28 31 28]
# Ciphertext :  [ 5  0  4 22  3 10 23 16  5 34 53 10 52  5 15]
# Ciphertext :  FAEWDKXQFh!KzFP
#
# Plaintext :  [27 40 26 41 44 27 40 33 26 46 47 27 26 30 27]
# Ciphertext :  [ 1 28 28 30 52 24 40 20 31 24 15  7  9  1 12]
# Ciphertext :  BbbdzYnUeYPHJBM
#
# Plaintext :  [38 27 39 26 39 31 39 28 35 27 51 27 35 26 42]
# Ciphertext :  [37 24 42 19 22  3 24 32 15 34 25 32 45 37  5]
# Ciphertext :  kYpTWDYfPhZfskF
#
# Plaintext :  [31 40 30 35 30 35 37 27 40 40 51 27 56 26  1]
# Ciphertext :  [39 20  8  3 12 35 23 23 37 50 53 38 10 39 12]
# Ciphertext :  mUIDMiXXkx!lKmM
#
# Plaintext :  [55  9 55 26  7 27 28 35 28 35 31 26 39 31 39]
# Ciphertext :  [47 37 22 47 40 10 24 34 53  9 23  6 44 47 52]
# Ciphertext :  ukWunKYh!JXGruz
#
# Plaintext :  [35 38 35 34 26 47 40 46 47 37 26 46 35 40 33]
# Ciphertext :  [16 34 36 28 54 27 26 45 44  9  9 39 14 16 39]
# Ciphertext :  Qhjb?a srJJmOQm
#
# Plaintext :  [33 27 38 26 36 27 47 34 26 30 27 44 35 26 42]
# Ciphertext :  [11 13  5 21  7 13  1 30 16 41 45 41 44 11 51]
# Ciphertext :  LNFVHNBdQosorLy
#
# Plaintext :  [47 45 27 46 26 37 41 46 27 26 30 31 40 33 27]
# Ciphertext :  [38 20 10 20 24 27 18 25 44 38 20 34 36 38 30]
# Ciphertext :  lUKUYaSZrlUhjld
#
# Plaintext :  [40 26 46 31 39 42 27 46 26 46 35 40 33 33 27]
# Ciphertext :  [21 12 48  6 33 51 12 51 16 51  5 23 31 21 18]
# Ciphertext :  VMvGgyMyQyFXeVS
#
# Plaintext :  [38 26 51 27 40 33 26 39 31 39 35 38 35 37 35]
# Ciphertext :  [31 29 50 35 41 25 35 14 36 51 29 29 21 31 23]
# Ciphertext :  ecxioZiOjyccVeX
#
# Plaintext :  [26 32 27 45 35 38 35 46 27 45 26 45 31 27 30]
# Ciphertext :  [51 24 12 52 18 44 35  4 33 43  9 47  0 51 40]
# Ciphertext :  yYMzSriEgqJuAyn
#
# Plaintext :  [27 40 51 27 55 26  1 27 34 37 27 40 26 28 31]
# Ciphertext :  [38 45  1 32  7  9 38 56 51 46 11 13 25 38 31]
# Ciphertext :  lsBfHJl,ytLNZle
#
# Plaintext :  [38 35 27 47 26 36 47 33 27 26 44 31 38 27 26]
# Ciphertext :  [16 55 40 15  9  2 44  7 23 44 35 19 15 16  4]
# Ciphertext :  Q.nPJCrHXriTPQE
#
# Plaintext :  [47 40 46 47 37 26 28 31 44 36 27 38 27 40 26]
# Ciphertext :  [ 3 54 17 46  9 17  0 47 33 40 14 10  1  3 34]
# Ciphertext :  D?RtJRAugnOKBDh
#
# Plaintext :  [37 27 37 35 26 30 27 44 35 26 46 31 39 42 27]
# Ciphertext :  [45 20 12 34 50 28 41 36 40 22 31  2 35 45  2]
# Ciphertext :  sUMhxbojnWeCisC
#
# Plaintext :  [46 26 46 35 40 33 33 27 38 26 37 31 26 37 27]
# Ciphertext :  [31 43 49 19 15 53 48 19 40 48  3 10  3 31 12]
# Ciphertext :  eqwTP!vTnvDKDeM
#
# Plaintext :  [39 42 47 45 26 34 27 40 51 27 26 30 31 39 35]
# Ciphertext :  [10 39 16 49 44 48 12 38  1  9 35 40 49 10  2]
# Ciphertext :  KmQwrvMlBJinwKC
#
# Plaintext :  [26 39 31 40 33 34 31 39 27 46 26 28 35 27 51]
# Ciphertext :  [15 12 21 36 10 36 46 43 16  0 18 33 56 15  2]
# Ciphertext :  PMVjKjtqQASg,PC
#
# Plaintext :  [27 26 46 44 27 40 45 42 41 44 46 27 45 35 55]
# Ciphertext :  [ 9  9 50 17 12 23 36  4 42  5  7 13 16  9 26]
# Ciphertext :  JJxRMXjEpFHNQJ
#
# Plaintext :  [26 18 31 38 27 35 40 26 35 46 47 56 26 45 31]
# Ciphertext :  [46 56 22 31  3 44 50 23 30 35  0  1 40 46 30]
# Ciphertext :  t,WeDrxXdiABntd
#
# Plaintext :  [38 27 39 27 26 39 31 40 31 39 42 47 34 26 18]
# Ciphertext :  [52 44 16 27 32 47 16 42 29 10 19 21 23 52 30]
# Ciphertext :  zrQafuQpcKTVXzd
#
# Plaintext :  [26 30 27 40 26 18 26 30 35 26  9 31 44 39 27]
# Ciphertext :  [18 27 41 51  0 26  2 28 32  8  6 39 19 18  2]
# Ciphertext :  SaoyA CbfIGmTSC
#
# Plaintext :  [40 56 26 28 31 38 35 27 47 26 45 31 39 42 27]
# Ciphertext :  [15 17 24 23 32 36  1 43  3 27  0 18 22 15 56]
# Ciphertext :  PRYXfjBqDaASWP,
#
# Plaintext :  [46 26 30 47 27 26 37 27 38 35 26 30 35 37 35]
# Ciphertext :  [ 5 23 37 35 11 38 33 49 21 29 44 16  7  5 17]
# Ciphertext :  FXkiLlgwVcrQHFR
#
# Plaintext :  [44 27 26 46 31 38 27 34 26 39 31 40 35 40 33]
# Ciphertext :  [ 5 12 43  1 21 21  8 43 34  5 43 49  3  5 17]
# Ciphertext :  FMqBVVIqhFqwDFR
#
# Plaintext :  [33 27 38 26 30 35 26  9 31 44 39 27 40 26 45]
# Ciphertext :  [50 41 44  3 47 46 22 51 32 45 41 26 23 50 15]
# Ciphertext :  xorDutWyfso XxP
#
# Plaintext :  [31 38 27 39 27 26 39 27 45 27 26 35 46 47 55]
# Ciphertext :  [12 13 50 29 21 47 26 22 53 28 29 13 44 12 13]
# Ciphertext :  MNxcVu W!bcNrMN
#
# Plaintext :  [26 13 27 39 47 40 26 36 31 44 35 34 26 42 27]
# Ciphertext :  [24 29  4 53  1  4  1  4  3  3 47 35  5 24 28]
# Ciphertext :  YcE!BEBEDDuiFYb
#
# Plaintext :  [51 27 34 26 28 31 38 35 27 47 26 27 37 34 35]
# Ciphertext :  [35  9 37 47 34  5 44 30 44 21 14 33 10 35 35]
# Ciphertext :  iJkuhFrdrVOgKii
#
# Plaintext :  [44 40 51 27 26 46 31 44 28 27 51 27 44 26 37]
# Ciphertext :  [38 16 53 52 46 26 39 30 22 35 56 37 33 38  5]
# Ciphertext :  lQ!zt mdWi,kglF
#
# Plaintext :  [27 44 31 40 27 26 39 31 45 37 35 42 47 40 26]
# Ciphertext :  [56 36 48 46 20 53 26  1 46 21 50 40 31 56  3]
# Ciphertext :  ,jvtU! BtVxne,D
#
# Plaintext :  [39 31 40 36 27 38 27 40 35 26 42 31 40 30 35]
# Ciphertext :  [52 29 12  8  5 23  8 40  9 18 18 14 52 52 49]
# Ciphertext :  zcMIFXInJSSOzzw
#
# Plaintext :  [30 35 37 27 40 26 30 31 40 33 27 40 26 28 35]
# Ciphertext :  [49 17 23 54  0 27 24 17  9  0 21 19  4 49 17]
# Ciphertext :  wRX?AaYRJAVTEwR
#
# Plaintext :  [27 51 27 26 51 27 40 33 26 46 31 44 28 27 46]
# Ciphertext :  [ 5 44 47 38 41 36 15 12 42 49 27 33 37  5 41]
# Ciphertext :  FrulojPMpwagkFo
#
# Plaintext :  [27 45 56 26  1 55  9 55 26  7 27 28 35 28 35]
# Ciphertext :  [27 29 44 11 26 51 36 47  0 23 50 32 26 27 26]
# Ciphertext :  acrL yjuAXxf a
#
# Plaintext :  [31 26 28 31 44 34 27 45 35 38 26 39 31 40 51]
# Ciphertext :  [40 44 54 17 48 43 23 34 33 47 21 35 41 40 12]
# Ciphertext :  nr?RvqXhguVionM
#
# Plaintext :  [31 38 31 45 27 35 37 27 40 26 42 31 40 30 35]
# Ciphertext :  [56 52 18 14 43 15 19 14 51  4  1 49 36 56 15]
# Ciphertext :  ,zSOqPTOyEBwj,P
#
# Plaintext :  [30 35 37 27 40 26 18 26 34 35 40 33 33 27 26]
# Ciphertext :  [ 2 21 15 48 15 21 56 31 56  6 52  1 12  2 16]
# Ciphertext :  CVPvPV,e,GzBMCQ
#
# Plaintext :  [18 26 30 31 40 33 27 40 26 38 47 27 44 26 28]
# Ciphertext :  [ 0 14 20 41 42 39 16 30 23 27 27 12 27  0  0]
# Ciphertext :  AOUopmQdXaaMaAA
#
# Plaintext :  [35 27 45 27 26 28 27 35 37 55 26 18 31 46 31]
# Ciphertext :  [ 5 47 50 40  0 18 12 24 18  9 48 10  4  5 38]
# Ciphertext :  FuxnASMYSJvKEFl
#
# Plaintext :  [38 27 34 26 38 47 38 47 45 26 18 26 27 37 34]
# Ciphertext :  [15 26 27 13 54 44 12 42 23 46 31 26 22 15 16]
# Ciphertext :  P aN?rMpXte WPQ
#
# Plaintext :  [35 44 40 51 27 26 28 31 38 35 27 47 26 28 31]
# Ciphertext :  [32 49 39 41 37 29 20  3 10  6 39 24 28 32 35]
# Ciphertext :  fwmokcUDKGmYbfi
#
# Plaintext :  [44 46 31 37 27 30 26 47 40 46 47 37 26 28 31]
# Ciphertext :  [47 45 53 52 40 42 40 22 51 26 24 21 44 47 31]
# Ciphertext :  us!znpnWy YVrue
#
# Plaintext :  [37 31 44 36 27 26 45 31 28 27 33 27 35 26 27]
# Ciphertext :  [18 55 17  4 51 46 22 12 17 37 14  4  6 18 12]
# Ciphertext :  S.REytWMRkOEGSM
#
# Plaintext :  [45 35 45 46 31 40 26 42 44 41 32 31 45 45 41]
# Ciphertext :  [31 26 56 52 18 10  4 35  5 56 44 19 43 31 54]
# Ciphertext :  e ,zSKEiF,rTqe?
#
# Plaintext :  [44 26 34 35 40 33 33 27 26 28 31 38 35 27 47]
# Ciphertext :  [48 10 37 43 55 22  0  1 51 19 23 30 39 48 43]
# Ciphertext :  vKkq.WAByTXdmvq
#
# Plaintext :  [26 39 31 40 30 27 42 27 46 26 37 31 45 31 39]
# Ciphertext :  [35 50  7  6 49 38 27 34  5  3 51 42 55 35 44]
# Ciphertext :  ixHGwlahFDyp.ir
#
# Plaintext :  [42 27 46 27 40 26 47 40 46 47 37 26 39 31 38]
# Ciphertext :  [45 38 16  5 51  6 19 44 43 41 12 32 53 45 21]
# Ciphertext :  slQFyGTrqoMf!sV
#
# Plaintext :  [27 40 36 47 46 37 27 40 26 18 26 30 31 40 33]
# Ciphertext :  [36 38 26  1 23 23 48 19 22 10 39 40 53 36  0]
# Ciphertext :  jl BXXvTWKmn!jA
#
# Plaintext :  [27 40 26 28 31 27 45 35 45 49 27 55 26 19 31]
# Ciphertext :  [13 29 16 56 41 42 33 20 32 38 34 30 42 13 18]
# Ciphertext :  NcQ,opgUflhdpNS
#
# Plaintext :  [42 27 46 26 45 27 27 46 26 47 45 35 27 26 26]
# Ciphertext :  [ 0 37  7 37 55 54  3 32  5 24 40 33 33  0 47]
# Ciphertext :  AkHk.?DfFYnggAu
#
# Plaintext :  [46 27 34 47 40 56 26  1 55  9 55 26  7 27 28]
# Ciphertext :  [ 0 17 28 41 11 43 30 55 56 19 45 26 49  0 53]
# Ciphertext :  ARboLqd.,Ts wA!
#
# Plaintext :  [35 28 35 31 26 44 31 45 39 35 26 39 31 39 42]
# Ciphertext :  [54 50 47 10 46 26 39  2  6 51 48 37  7 54  9]
# Ciphertext :  ?xuKt mCGyvkH?J
#
# Plaintext :  [31 44 41 38 31 34 26 33 31 38 27 44 26  3 41]
# Ciphertext :  [45  1  2 53 19 30 32 39 43  5 13 15 12 45 43]
# Ciphertext :  sBC!TdfmqFNPMsq
#
# Plaintext :  [37 46 41 44 26 28 35 30 27 40 33 26 46 31 37]
# Ciphertext :  [36  3 51 24 18 51 44 38 50 15  9 34  8 36 15]
# Ciphertext :  jDyYSyrlxPJhIjP
#
# Plaintext :  [40 41 38 41 33 35 26 42 31 45 27 49 27 46 26]
# Ciphertext :  [10 45 25 36 20 26 12  1 11 10  8 33 45 10  4]
# Ciphertext :  KsZjU MBLKIgsKE
#
# Plaintext :  [46 31 44 28 27 40 33 26 30 35 26  9 31 44 39]
# Ciphertext :  [ 2 44 41 34 43 11 37  2 34 34 33 38 28  2 51]
# Ciphertext :  CrohqLkChhglbCy
#
# Plaintext :  [27 40 55 26 20 45 35 27 26 26 46 27 34 47 40]
# Ciphertext :  [52 49 13 36 16 14 21 40  9 45 53 50  7 52 10]
# Ciphertext :  zwNjQOVnJs!xHzK
#
# Plaintext :  [26 30 31 40 33 27 40 26 33 31 38 27 44 26  3]
# Ciphertext :  [18  9  2 26 50 47 53 11  5 56 25 30 52 18 50]
# Ciphertext :  SJC xu!LF,ZdzSx
#
# Plaintext :  [41 37 46 41 44 26 28 35 45 27 26 30 35 28 35]
# Ciphertext :  [19 33 20  1  4 20 44  6 37 13 34 11 37 19 30]
# Ciphertext :  TgUBEUrGkNhLkTd
#
# Plaintext :  [38 27 40 33 26 47 45 35 27 26 51 27 40 33 26]
# Ciphertext :  [44 11 28 32 43 22 36  7  0 34 30 17 44 44 46]
# Ciphertext :  rLbfqWjHAhdRrrt
#
# Plaintext :  [45 27 40 33 27 46 26 28 31 38 35 27 55 26  1]
# Ciphertext :  [45 36 49 48  5 17 41  7 24 20 12 24 50 45  3]
# Ciphertext :  sjwvFRoHYUMYxsD
#
# Plaintext :  [27 34 37 27 40 26 28 27 40 51 27 37 26 51 27]
# Ciphertext :  [16  1 10 14 20 21 54 38 49 12 20 53 28 16 54]
# Ciphertext :  QBKOUV?lwMU!bQ?
#
# Plaintext :  [40 33 26 46 35 30 27 37 26 42 31 44 29 27 51]
# Ciphertext :  [15 53 12 47 31 36 26 32 10 36 14 36 45 15  7]
# Ciphertext :  P!Muej fKjOjsPH
#
# Plaintext :  [27 26 28 31 38 35 27 47 26 39 31 44 47 42 27]
# Ciphertext :  [22 27 42 51 16 44  4  2  9 45 29 23  1 22 38]
# Ciphertext :  WapyQrECJscXBWl
#
# Plaintext :  [37 27 40 26 38 47 38 47 45 27 40 26 18 56 26]
# Ciphertext :  [ 5 25 49  8  3 36  8 47 53 13 23 56 49  5 47]
# Ciphertext :  FZwIDjIu!NX,wFu
#
# Plaintext :  [39 31 40 33 35 40 33 27 46 26 49 27 36 27 34]
# Ciphertext :  [25 32 19 14 20  8 29 44  8 36 42 44  0 25 16]
# Ciphertext :  ZfTOUIcrIjprAZQ
#
# Plaintext :  [26 28 31 38 35 27 47 26 51 27 40 33 26 28 27]
# Ciphertext :  [39 36  0 48 22 35 22 37 39  0 47 42 29 39  8]
# Ciphertext :  mjAvWiWkmAupcmI
#
# Plaintext :  [28 51 26 32 27 29 31 55 26 18 31 38 27 39 27]
# Ciphertext :  [ 4  9 29 37  4 16  0 17  4 43 13 36 52  4 15]
# Ciphertext :  EJckEQAREqNjzEP
#
# Plaintext :  [26 34 35 30 47 42 26 30 35 26  9 31 44 39 27]
# Ciphertext :  [50 18 11 15 44 56 33 52 35  7 13 21 20 50 50]
# Ciphertext :  xSLPr,gziHNVUxx
#
# Plaintext :  [40 56 26  1 55  9 55 26  7 27 28 35 28 35 31]
# Ciphertext :  [14 39 15 55 20 27 31 40 54 36 11 16 29 14  3]
# Ciphertext :  OmP.Uaen?jLQcOD
#
# Plaintext :  [26 39 31 40 36 27 30 35 26 46 31 44 28 35 27]
# Ciphertext :  [ 3 50 11 14 28 33 41 55 51 50  2  2 50  3  0]
# Ciphertext :  DxLObgo.yxCCxDA
#
# Plaintext :  [45 27 26 47 40 46 47 37 26 39 31 40 33 27 46]
# Ciphertext :  [16  2 40 55  3 18 34  0 35 46  3 14 52 16 10]
# Ciphertext :  QCn.DShAitDOzQK
#
# Plaintext :  [27 45 35 26 45 31 33 27 38 27 26 42 31 44 39]
# Ciphertext :  [45 51 42 23 29 13  2 49 38 19 10 34 32 45  1]
# Ciphertext :  sypXcNCwlTKhfsB
#
# Plaintext :  [27 45 27 38 27 34 27 40 26 45 31 40 30 35 44]
# Ciphertext :  [34 12 33 18 29 33 38 14 50 48 39 20 19 34 43]
# Ciphertext :  hMgScglOxvmUThq
#
# Plaintext :  [35 55 26  1 27 34 37 27 40 56 26 28 31 38 35]
# Ciphertext :  [ 2  1  0 36 19 50 20 49 25 38 41 56 35  2 15]
# Ciphertext :  CBAjTxUwZlo,iCP
#
# Plaintext :  [27 47 26 36 47 33 27 26 39 27 45 35 34 26 39]
# Ciphertext :  [ 9 45 13 28 10 13 53  8 29 27 40 48 34  9 19]
# Ciphertext :  JsNbKN!IcanvhJT
#
# Plaintext :  [31 40 31 44 27 42 37 27 40 26 40 35 38 27 35]
# Ciphertext :  [11 10 56 52 47 36 48 24 24 12 55 46 26 11 19]
# Ciphertext :  LK,zujvYYM.t LT
#
# Plaintext :  [40 35 38 27 35 26 51 27 40 33 26 45 47 30 27]
# Ciphertext :  [44 24 45 35 27  7 34 21  2 13 20  2 50 44 20]
# Ciphertext :  rYsiaHhVCNUCxrU
#
# Plaintext :  [34 26 30 35 27 36 27 44 37 27 40 26 41 44 27]
# Ciphertext :  [48 28  4 28  0  0 27  4 46 45 35 31 37 48 15]
# Ciphertext :  vbEbAAaEtsiekvP
#
# Plaintext :  [40 33 26 46 47 27 40 51 27 26 45 31 38 27 39]
# Ciphertext :  [ 7 12 12 31 46  5 12 13 32 36 11 40 22  7 35]
# Ciphertext :  HMMetFMNfjLnWHi
#
# Plaintext :  [27 26 30 35 26  8 40 30 41 40 31 45 35 27 26]
# Ciphertext :  [37 41 45 34 17 29 45 52 46 36 17 43  8 37 29]
# Ciphertext :  koshRcsztjRqIkc
#
# Plaintext :  [30 47 38 47 26 45 27 27 46 26 39 31 40 36 27]
# Ciphertext :  [36  9 49 21 39 44 55 44 43 16 46 17 37 36 37]
# Ciphertext :  jJwVmr.rqQtRkjk
#
# Plaintext :  [38 27 40 35 26 37 31 34 35 30 47 42 27 40 26]
# Ciphertext :  [14 46  7 32 34 47 38  8 45 14  5 23  2 14 26]
# Ciphertext :  OtHfhulIsOFXCO
#
# Plaintext :  [30 35 26  9 31 44 39 27 40 55 26 18 27 38 27]
# Ciphertext :  [42  7 27  2 49 50  9 56  6 49  8 11 38 42  7]
# Ciphertext :  pHaCwxJ,GwILlpH
#
# Plaintext :  [34 26 45 27 46 47 26 34 27 38 26 51 27 40 33]
# Ciphertext :  [29 38 16 41 14 30 51 40  5 27  8 28 54 29 14]
# Ciphertext :  clQoOdynFaIb?cO
#
# Plaintext :  [26 28 31 38 35 27 47 26 45 47 37 27 35 26 30]
# Ciphertext :  [44 53 11 46 45 20 13 29 21  8  5  4 37 44 49]
# Ciphertext :  r!LtsUNcVIFEkrw
#
# Plaintext :  [35 26  9 31 44 39 27 40 26 27 30 27 38 27 34]
# Ciphertext :  [24 21 16 41 51 23 43 27 55  4 39 42 16 24 55]
# Ciphertext :  YVQoyXqa.EmpQY.
#
# Plaintext :  [26 42 31 44 42 47 45 46 27 37 27 27 40 40 51]
# Ciphertext :  [47 19 42 27 15 33 38  1  9 14 27 49 51 47 41]
# Ciphertext :  uTpaPglBJOawyuo
#
# Plaintext :  [27 55 26 12 31 40 47 44 47 46 26 28 31 38 35]
# Ciphertext :  [52 47 26 40 18 22 13 12 44  5 17 19 42 52  4]
# Ciphertext :  zu nSWNMrFRTpzE
#
# Plaintext :  [27 47 56 26 42 31 44 42 47 45 46 27 37 27 27]
# Ciphertext :  [19 19 39 55 33 25 22 28 23 49  7 20 18 19 32]
# Ciphertext :  TTm.gZWbXwHUSTf
#
# Plaintext :  [40 26 30 35 26  9 31 44 39 27 40 26 28 47 37]
# Ciphertext :  [34 45 35 39 45 45 41 22  8  1  8 49  6 34 45]
# Ciphertext :  hsimssoWIBIwGhs
#
# Plaintext :  [27 26 38 31 28 35 34 26 38 27 39 27 26 30 27]
# Ciphertext :  [54 34 41 47 33  2  8 37 42 55 15 55 21 54 18]
# Ciphertext :  ?hougCIkp.P.V?S
#
# Plaintext :  [40 26 38 31 28 35 34 26 28 31 28 27 45 26 47]
# Ciphertext :  [56 55 32 35 12 54  8 36 21 26  2 20 39 56 47]
# Ciphertext :  ,.fiM?IjV CUm,u
#
# Plaintext :  [40 46 47 37 26 30 35 37 47 40 36 47 40 33 35]
# Ciphertext :  [41 13  3 37 54 17 43  3 52 38 36  5 33 41 51]
# Ciphertext :  oNDk?RqDzljFgoy
#
# Plaintext :  [55 26  7 27 38 26 35 40 35 26 39 31 39 28 47]
# Ciphertext :  [ 8  8 23 53 38  2  3 49 45 45 12 52 22  8 33]
# Ciphertext :  IIX!lCDwssMzWIg
#
# Plaintext :  [27 46 26  1 55  9 55 26  7 27 28 35 28 35 31]
# Ciphertext :  [21 47 51 11 41 38 14 24 44 11 11 26 45 21 11]
# Ciphertext :  VuyLolOYrLL sVL
#
# Plaintext :  [26 39 31 44 27 45 27 26 39 31 39 35 38 35 37]
# Ciphertext :  [ 7 45 49 25 46 27 25 36 19 27 30 24 15  7 52]
# Ciphertext :  HswZtaZjTadYPHz
#
# Plaintext :  [35 26 37 31 45 31 39 42 27 46 27 40 26 51 27]
# Ciphertext :  [33  6 17 39 45 52 33 32  8 24 20 17 43 33  2]
# Ciphertext :  gGRmszgfIYURqgC
#
# Plaintext :  [40 33 26 38 31 28 35 34 26 28 31 45 27 44 26]
# Ciphertext :  [29 50 40 34 29 43 22 36 45  9 37 54 55 29 54]
# Ciphertext :  cxnhcqWjsJk?.c?
#
# Plaintext :  [30 27 38 27 39 26 34 27 38 26 39 31 40 27 39]
# Ciphertext :  [40  3 14  9 39 13 32 34  0 50 23 29 23 40 19]
# Ciphertext :  nDOJmNfhAxXcXnT
#
# Plaintext :  [28 27 34 26 49 27 49 27 45 27 40 26 30 27 40]
# Ciphertext :  [30 42 51 12 54 32 10 19 36 25 37  3 54 30 11]
# Ciphertext :  dpyM?fKTjZkD?dL
#
# Plaintext :  [26 42 31 40 33 31 46 27 34 47 27 40 26 45 31]
# Ciphertext :  [20 55  4  4 49 42 48 21 27 23 32 16 25 20 29]
# Ciphertext :  U.EEwpvVaXfQZUc
#
# Plaintext :  [38 27 39 27 26 30 35 26  9 31 44 39 27 40 55]
# Ciphertext :  [ 1 51 42  9 34 27 13 29 12 56 34 38 38  1 47]
# Ciphertext :  BypJhaNcM,hllBu
#
# Plaintext :  [26 11 31 28 35 34 26 30 27 44 35 26 35 46 47]
# Ciphertext :  [ 5  9 35 20 46 30 10 14  8  9 11 21 43  5 42]
# Ciphertext :  FJiUtdKOIJLVqFp
#
# Plaintext :  [56 26 27 30 27 26 45 27 46 47 26 29 31 44 35]
# Ciphertext :  [11 35  6  9 14 12 46 33 35 28 21 20 36 11 28]
# Ciphertext :  LiGJOMtgibVUjLb
#
# Plaintext :  [46 27 26 38 47 29 47 26 51 27 40 33 26 30 35]
# Ciphertext :  [16  5 29 54 19  5 14  0 54 11 56 40 36 16 17]
# Ciphertext :  QFc?TFOA?L,njQR
#
# Plaintext :  [27 38 27 39 35 26 28 31 38 35 27 47 26 45 27]
# Ciphertext :  [ 0 34 29 39 47  9 33  9 13 13 49 15 25  0 51]
# Ciphertext :  AhcmuJgJNNwPZAy
#
# Plaintext :  [27 46 26 39 31 40 31 39 42 47 34 26 45 46 47]
# Ciphertext :  [ 3 40 22  7 38 43  7 25  9 28  6 25 29  3 38]
# Ciphertext :  DnWHlqHZJbGZcDl
#
# Plaintext :  [30 35 26 30 35 26  9 31 44 39 27 40 55 26 10]
# Ciphertext :  [11 47 12 26 11 11 38 40 14 10 10 10 36 11 17]
# Ciphertext :  LuM LLlnOKKKjLR
#
# Plaintext :  [31 39 27 39 42 47 27 40 26 28 27 34 27 45 27]
# Ciphertext :  [53 18  6 10 35 47 42 45 45 52 28 34 50 53  3]
# Ciphertext :  !SGKiupsszbhx!D
#
# Plaintext :  [26  9 31 44 39 27 40 26  1 55  9 55 26  7 27]
# Ciphertext :  [53 47 56 43 26 13 32 17 29 45 34  0  7 53  7]
# Ciphertext :  !u,q NfRcshAH!H
#
# Plaintext :  [28 35 28 35 31 26 51 27 40 33 26 30 35 26 27]
# Ciphertext :  [ 1  0 39  7 35 30 27 48 13 20 16 19 18  1 14]
# Ciphertext :  BAmHidavNUQTSBO
#
# Plaintext :  [46 27 45 26 44 27 46 27 44 27 46 27 26 47 40]
# Ciphertext :  [45 48 40 44 51 31 34 13 55  2 11 17 32 45 37]
# Ciphertext :  svnryehN.CLRfsk
#
# Plaintext :  [46 47 37 26 41 44 27 40 33 26 27 45 35 40 33]
# Ciphertext :  [11 33 41  8 37 28 26  5 39 50  3 35 23 11 38]
# Ciphertext :  LgoIkb FmxDiXLl
#
# Plaintext :  [26 39 31 39 28 47 27 46 26 46 31 39 27 40 46]
# Ciphertext :  [50  9 38 33 46  5 21 29 56 47 14 30 54 50  2]
# Ciphertext :  xJlgtFVc,uOd?xC
#
# Plaintext :  [31 39 27 40 26 28 31 38 35 27 47 26 39 31 39]
# Ciphertext :  [18 49 37  1 23 19  6 56 44 56 19 47  3 18  7]
# Ciphertext :  SwkBXTG,r,TuDSH
#
# Plaintext :  [42 31 44 46 27 40 51 27 37 27 40 26 37 31 46]
# Ciphertext :  [36 20 53 50 35  8 36 39 16 51 43 11 16 36 38]
# Ciphertext :  jU!xiIjmQyqLQjl
#
# Plaintext :  [47 44 47 40 27 40 26 30 27 40 26 36 47 33 27]
# Ciphertext :  [25 35 28 29 31 49 26 36 41 27 39 49  2 25 49]
# Ciphertext :  Zibcew joamwCZw
#
# Plaintext :  [26 27 45 27 38 26 47 45 47 38 26 28 31 38 35]
# Ciphertext :  [39 51 17 48  3 55 50 35 29  3 19  5 39 39  8]
# Ciphertext :  myRvD.xicDTFmmI
#
# Plaintext :  [27 47 55 26  1 27 34 37 27 40 26 42 27 30 27]
# Ciphertext :  [23 24 45 29  3 14 10 12 38  5  7  6 39 23 33]
# Ciphertext :  XYscDOKMlFHGmXg
#
# Plaintext :  [26 27 37 34 35 44 40 51 27 26 28 31 38 35 27]
# Ciphertext :  [30  2 22 35 50 16 44 25 23 29  0 49 26 30 31]
# Ciphertext :  dCWixQrZXcAw de
#
# Plaintext :  [47 26 34 27 44 47 45 26 39 31 40 36 27 49 27]
# Ciphertext :  [ 3 19 33 43 17 55  1  2 43 15 53 47 35  3 28]
# Ciphertext :  DTgqR.BCqP!uiDb
#
# Plaintext :  [28 26 30 31 40 33 27 40 26 29 27 40 30 27 27]
# Ciphertext :  [41 24 24 30 22 14 18 45 46 55 35 27 36 41 33]
# Ciphertext :  oYYdWOSst.iajog
#
# Plaintext :  [40 26 28 27 34 49 27 26 27 51 27 34 40 51 27]
# Ciphertext :  [ 2 39 36 31 23 54 13 41 12 18 45 32 11  2 43]
# Ciphertext :  CmjeX?NoMSsfLCq
#
# Plaintext :  [26 37 27 40 35 28 27 38 26 42 31 44 40 27 34]
# Ciphertext :  [17 52 27  9 27 35 31 31 36 16 30 30  7 17 22]
# Ciphertext :  RzaJaieejQddHRW
#
# Plaintext :  [26 39 27 37 27 40 26 30 27 33 35 40 33 26 41]
# Ciphertext :  [23  5 22 38 25 21 21 24 29 38 34 22 49 23 18]
# Ciphertext :  XFWlZVVYclhWwXS
#
# Plaintext :  [44 27 40 33 26  9 31 44 39 27 40 26 45 31 34]
# Ciphertext :  [44 12 21 22  7  7 42 16 39 50 35 38 39 44 17]
# Ciphertext :  rMVWHHpQmxilmrR
#
# Plaintext :  [35 40 33 33 27 26 45 31 36 27 37 26 45 27 27]
# Ciphertext :  [53 48  5 21 20  9 46 19 20 44  2 28 42 53 33]
# Ciphertext :  !vFVUJtTUrCbp!g
#
# Plaintext :  [46 26 35 46 47 26 28 31 38 35 27 47 26 39 31]
# Ciphertext :  [ 1 33 42 41 14 27 42 23 26  2 21 39 28  1 28]
# Ciphertext :  BgpoOapX CVmbBb
#
# Plaintext :  [39 35 38 35 37 35 26 30 27 44 27 34 26  9 31]
# Ciphertext :  [25 47 55  4  1 43 47 52 16  7  1 24 47 25 33]
# Ciphertext :  Zu.EBquzQHBYuZg
#
# Plaintext :  [44 39 27 40 55 26 10 41 39 35 46 39 31 40 26]
# Ciphertext :  [30 23 26 38 15 44 30 32 44 36 36 46 32 30 46]
# Ciphertext :  dX lPrdfrjjtfdt
#
# Plaintext :  [30 27 40 26 46 31 37 27 30 26 28 31 38 35 27]
# Ciphertext :  [38 15 44 30  8 13 53  1 19 53 51 53 24 38 44]
# Ciphertext :  lPrdIN!BT!y!Ylr
#
# Plaintext :  [47 26 47 40 46 47 37 26 39 31 40 36 27 30 35]
# Ciphertext :  [12 40  4 27 21  8 38 45 16 49 31 52 44 12 20]
# Ciphertext :  MnEaVIlsQwezrMU
#
# Plaintext :  [26 51 27 40 33 26 46 31 44 28 27 35 37 26 30]
# Ciphertext :  [54 43  6 55 27 43 19 24 54  4 18 35 41 54 32]
# Ciphertext :  ?qG.aqTY?ESio?f
#
# Plaintext :  [27 40 26 39 31 38 31 28 35 34 35 26 41 44 27]
# Ciphertext :  [15 28 25 46 30  6  7 41 35 32 16 44 23 15 15]
# Ciphertext :  PbZtdGHoifQrXPP
#
# Plaintext :  [40 33 41 44 27 40 33 26 30 35 26  9 31 44 39]
# Ciphertext :  [23 34 24 25 24 47 51 29  2 41 20 51 31 23 41]
# Ciphertext :  XhYZYuycCoUyeXo
#
# Plaintext :  [27 40 26 30 27 38 27 39 26 34 27 38 26 42 31]
# Ciphertext :  [ 1 39  9 14 28 15 20 15 33 41 13  6 39  1 52]
# Ciphertext :  BmJObPUPgoNGmBz
#
# Plaintext :  [40 33 31 46 27 34 47 27 40 26 28 31 44 34 27]
# Ciphertext :  [36 34 13 22 42 49 33 52 55 51 50 56 50 36 36]
# Ciphertext :  jhNWpwgz.yx,xjj
#
# Plaintext :  [45 35 38 26 39 31 39 28 47 27 46 26 28 31 38]
# Ciphertext :  [24 30 23 25 17 32  7 12 30 33  4 34  8 24 23]
# Ciphertext :  YdXZRfHMdgEhIYX
#
# Plaintext :  [35 27 47 26 30 35 27 37 47 35 26 37 31 39 27]
# Ciphertext :  [ 7  0 46 39  0 46 22 46 43 24 36 23 19  7 49]
# Ciphertext :  HAtmAtWtqYjXTHw
#
# Plaintext :  [39 42 47 27 40 40 51 27 26 41 38 31 34 26 30]
# Ciphertext :  [24 49 17 16 38 31 50  5 25 10 34 28  6 24 20]
# Ciphertext :  YwRQlexFZKhbGYU
#
# Plaintext :  [47 40 35 27 55 26  1 27 34 37 27 40 26 34 35]
# Ciphertext :  [32 40 12 33  8 21 46 42 47 43 38 22 27 32 19]
# Ciphertext :  fnMgIVtpuqlWafT
#
# Plaintext :  [40 33 33 27 26 45 27 27 46 26 35 40 35 26 28]
# Ciphertext :  [50 39 34 35 11  2  2 56 12  8 55 48 47 50 28]
# Ciphertext :  xmhiLCC,MI.vuxb
#
# Plaintext :  [31 38 35 27 47 26 30 35 37 31 40 27 38 26 45]
# Ciphertext :  [16  4 17 14 46  6 47 36 28 25 52 47  4 16 42]
# Ciphertext :  QEROtGujbZzuEQp
#
# Plaintext :  [31 28 27 33 27 35 26 45 41 45 41 37 26 51 27]
# Ciphertext :  [16 52  5 38 28 49 50 43 20  5 20 19 45 16 48]
# Ciphertext :  QzFlbwxqUFUTsQv
#
# Plaintext :  [40 33 26 36 31 40 35 47 45 26 30 27 40 26 30]
# Ciphertext :  [12 29 34 12 22  1 29 28 24 10 20  3 46 12 36]
# Ciphertext :  MchMWBcbYKUDtMj
#
# Plaintext :  [35 37 27 33 47 39 35 26 41 38 31 34 26 30 47]
# Ciphertext :  [11 19 39 52 47 38  8 17 36  9  2 26  5 11 16]
# Ciphertext :  LTmzulIRjJC FLQ
#
# Plaintext :  [40 35 27 26 37 34 47 45 47 45 40 51 27 26 42]
# Ciphertext :  [24 49 23 19 38  4 32 31 36 21 31 54 22 24  1]
# Ciphertext :  YwXTlEfejVe?WYB
#
# Plaintext :  [27 44 27 26 42 31 40 30 47 30 47 37 26 27 45]
# Ciphertext :  [31 22  1 49 33  7 15 44 46 25  4 38 51 31 51]
# Ciphertext :  eWBwgHPrtZElyey
#
# Plaintext :  [38 35 26  9 31 44 39 27 40 26 38 34 41 55 23]
# Ciphertext :  [37 30 14 31 34 55 37  7 13 18 53 50 29 37 12]
# Ciphertext :  kdOeh.kHNS!xckM
#
# Cipher Text :  pHQRRGqLUgpqmpEhfiyuFoiFf!vIhFiosnZyEFRqybliHfAVKx.jhOmfk?fQVlZetEqOYcIAUV?JOyOlWrleANEkJthPxuTGXtd?ndxhhwTtHu!LkGsOUPwvMvaCwvckbZlPuMLRw LABldPHJHDRsFxgrDEPtSdTTFFnkRmKV hkKZHkvkhRASsleccjOsufRiHnaFbaLZcKSxiHYHb,hfPv?RcFTtHrfGBuVeOjxwcoPfUy!cqIISQWGVKjyDshtT!GnCIB!dfsWmo,eRcZ!IPnChmiUYMzftyrVJPGWUx zdesdaOycuk. EIPPYgcccTYMuEI?tEC QLoaRcJdst,,.v.!mekoUcXL,aGlrOVzOIiscB,GhcZtmOjZGTRGJIcEVmOJfP wkDIy VnmbGSwvEJWFMFNmvVycFpcTOZnKDvVdQsbq,kcuBKymSQz?oBDHQmhfBWs!?vFUPoUmkiaH yeFoTZjzBWYmwg!MwTNqo,E?mnZHAhaOqsYHuQF auevPY.YY!FfgXDqEWhCU!!sbgaYPD,oaqttebbtadzRUziEzZVgtimcbLmyT VmYdqmZYiOQoyAJVyiUQY.,tqocLwoBa?XR,VjnuHuXfWHmYeIjUqoJZtkuhpMuSHqyDVGftmB.OlvSaDvbu,uRXc.,FYqcbdRrlVrIWuoJfPBRfNMd YjgqtgpA.NPppmBUOcBHWzOXp,uvjKmMedkvPiRuefLnIrbaaeNiCRfxhRhApdMRkMmV!hsr,CvvkM.IxUCxrPofa.oMjqceVnYokaoCLNfEJgCAbCa,EyUJvWkbANKNvEakEuWQcZHOWqQJkvETtXFmNpqMnSXEFORVC!FMYWsnmyOM?HaegybmiWKp ?N?xioRMOppbMdT?BZmeLIa!y!IElAZETDRPeIAvetbBuT,EGPsVSePAFquiEqul,rmTPbmPSNWuOcMFpZBUThtnpycc!hX?WRk?HQDaK!BHbNogB!F!iAruHoGavpNIfZLRjoPGpHyk,OLVUNXXW!Heu,CZDVFRRqcQQuNzMkGsCsNqsOqjzOSYp!bzQMUtOwHSg,TtmRDUlKw!k?,IzfUM,MwAZCTRezQuzBIf,CxpokGtu,TLXGkKpuhzfXPTVsBQYEF,Fc.I?QstmOKgGX!pKMgnsmZuGlrpZPeWG.rduvPvEzCur,JfvDDP,SZxWqBhvMBuqnSxBnzDxLrlNETIcBrT?ASLkutG!WUdTZ!i,FwtaIysJFN!Dbsl!pYvsiiWaFbPbOlheqKKnRjsubHvphgzNbUkxmNovPqJWHOG QkFbrnqzmpKLQtPCTnk?CmfzzEZNKTNXfktnzSl ZgJBtJMdNnalMsnwvOcN?FWQWAsUPRnLIZwKfruxyPyiqpeAh!QOVWMTijRtff,CSNaSZJlRJCKPQroSip,U?nCMCXtYJYNyUt.yoCPUvseKWGmx?q!FUUTcAfSfMVOBxwCTvVMjJEoFsmIChRVzpOX wIuyVwchmpuHljntS!S MprWHyDhQMLoM,!xYajDkvPqbs.c.nKnnFvKUdxhZnrsYBpJ,UKnEdbPeYkACzkjnxQgehQTPbeiFMkQIw eCsLRKq,NSAwDQcncKPO,FOzFdQtpmlcrj.QZSPuWpCpGej vHLsuFgOpxYBcRHr?!obW!LYRsZ!cdO.OJVuTxsGvjowMGEL!RD!JvMuAxVMjJspbY?WuJEGmlUjDFfUvvNEBOhvpntcnDty,eOMaQbQVDKWZI?mwardaKTDijWBQrhRddyIAcCRxAU!, GycSaKrDBxGGOUgFSbHUZKPfjlByUB HpFAEWDKXQFh!KzFPBbbdzYnUeYPHJBMkYpTWDYfPhZfskFmUIDMiXXkx!lKmMukWunKYh!JXGruzQhjb?a srJJmOQmLNFVHNBdQosorLylUKUYaSZrlUhjldVMvGgyMyQyFXeVSecxioZiOjyccVeXyYMzSriEgqJuAynlsBfHJl,ytLNZleQ.nPJCrHXriTPQED?RtJRAugnOKBDhsUMhxbojnWeCisCeqwTP!vTnvDKDeMKmQwrvMlBJinwKCPMVjKjtqQASg,PCJJxRMXjEpFHNQJ t,WeDrxXdiABntdzrQafuQpcKTVXzdSaoyA CbfIGmTSCPRYXfjBqDaASWP,FXkiLlgwVcrQHFRFMqBVVIqhFqwDFRxorDutWyfso XxPMNxcVu W!bcNrMNYcE!BEBEDDuiFYbiJkuhFrdrVOgKiilQ!zt mdWi,kglF,jvtU! BtVxne,DzcMIFXInJSSOzzwwRX?AaYRJAVTEwRFrulojPMpwagkFoacrL yjuAXxf a nr?RvqXhguVionM,zSOqPTOyEBwj,PCVPvPV,e,GzBMCQAOUopmQdXaaMaAAFuxnASMYSJvKEFlP aN?rMpXte WPQfwmokcUDKGmYbfius!znpnWy YVrueS.REytWMRkOEGSMe ,zSKEiF,rTqe?vKkq.WAByTXdmvqixHGwlahFDyp.irslQFyGTrqoMf!sVjl BXXvTWKmn!jANcQ,opgUflhdpNSAkHk.?DfFYnggAuARboLqd.,Ts wA!?xuKt mCGyvkH?JsBC!TdfmqFNPMsqjDyYSyrlxPJhIjPKsZjU MBLKIgsKECrohqLkChhglbCyzwNjQOVnJs!xHzKSJC xu!LF,ZdzSxTgUBEUrGkNhLkTdrLbfqWjHAhdRrrtsjwvFRoHYUMYxsDQBKOUV?lwMU!bQ?P!Muej fKjOjsPHWapyQrECJscXBWlFZwIDjIu!NX,wFuZfTOUIcrIjprAZQmjAvWiWkmAupcmIEJckEQAREqNjzEPxSLPr,gziHNVUxxOmP.Uaen?jLQcODDxLObgo.yxCCxDAQCn.DShAitDOzQKsypXcNCwlTKhfsBhMgScglOxvmUThqCBAjTxUwZlo,iCPJsNbKN!IcanvhJTLK,zujvYYM.t LTrYsiaHhVCNUCxrUvbEbAAaEtsiekvPHMMetFMNfjLnWHikoshRcsztjRqIkcjJwVmr.rqQtRkjkOtHfhulIsOFXCO pHaCwxJ,GwILlpHclQoOdynFaIb?cOr!LtsUNcVIFEkrwYVQoyXqa.EmpQY.uTpaPglBJOawyuozu nSWNMrFRTpzETTm.gZWbXwHUSTfhsimssoWIBIwGhs?hougCIkp.P.V?S,.fiM?IjV CUm,uoNDk?RqDzljFgoyIIX!lCDwssMzWIgVuyLolOYrLL sVLHswZtaZjTadYPHzgGRmszgfIYURqgCcxnhcqWjsJk?.c?nDOJmNfhAxXcXnTdpyM?fKTjZkD?dLU.EEwpvVaXfQZUcBypJhaNcM,hllBuFJiUtdKOIJLVqFpLiGJOMtgibVUjLbQFc?TFOA?L,njQRAhcmuJgJNNwPZAyDnWHlqHZJbGZcDlLuM LLlnOKKKjLR!SGKiupsszbhx!D!u,q NfRcshAH!HBAmHidavNUQTSBOsvnryehN.CLRfskLgoIkb FmxDiXLlxJlgtFVc,uOd?xCSwkBXTG,r,TuDSHjU!xiIjmQyqLQjlZibcew joamwCZwmyRvD.xicDTFmmIXYscDOKMlFHGmXgdCWixQrZXcAw deDTgqR.BCqP!uiDboYYdWOSst.iajogCmjeX?NoMSsfLCqRzaJaieejQddHRWXFWlZVVYclhWwXSrMVWHHpQmxilmrR!vFVUJtTUrCbp!gBgpoOapX CVmbBbZu.EBquzQHBYuZgdX lPrdfrjjtfdtlPrdIN!BT!y!YlrMnEaVIlsQwezrMU?qG.aqTY?ESio?fPbZtdGHoifQrXPPXhYZYuycCoUyeXoBmJObPUPgoNGmBzjhNWpwgz.yx,xjjYdXZRfHMdgEhIYXHAtmAtWtqYjXTHwYwRQlexFZKhbGYUfnMgIVtpuqlWafTxmhiLCC,MI ...
